# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
import pickle

# %%
import pandas as pd

# %% [markdown]
# # DB 연결

# %%
# pickle 모듈 이용, db 정보 가져옴
with open('/Users/bella/GitHub/FastAPI/database/db_dict.pickle','rb') as f :
    db_info = pickle.load(f)

# %%
db_info
# Out:
# {'DB_USERNAME': 'root',
#  'DB_PASSWORD': 'root123',
#  'DB_HOST': '52.78.168.253',
#  'DB_PORT': 59543,
#  'DB_DATABASE': 'cocomong'}

# %%
DB_USERNAME : str = db_info.get("DB_USERNAME")
DB_PASSWORD = db_info.get("DB_PASSWORD")
DB_HOST : str = db_info.get("DB_HOST","localhost")
DB_PORT : str = db_info.get("DB_PORT",3306)
DB_DATABASE : str = db_info.get("DB_DATABASE")
    
DB_URL = f"mysql+pymysql://{DB_USERNAME}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_DATABASE}"

# %%
engine = create_engine(DB_URL)

# %%
# db 연결
conn = engine.connect()

# %%
conn

# %% [markdown]
# # DB에 데이터 넣기

# %%
df = pd.read_csv("pollutant_df.csv")
df
# Out:
#        SO2_incheon_0  CO_incheon_0  O3_incheon_0  NO2_incheon_0  \
# 0              0.007           0.2         0.015          0.004
# 1              0.007           0.2         0.015          0.005
# 2              0.007           0.1         0.015          0.004
# 3              0.006           0.1         0.014          0.004
# 4              0.007           0.1         0.014          0.004
# ...              ...           ...           ...            ...
# 67171          0.003           0.3         0.027          0.003
# 67172          0.002           0.3         0.023          0.003
# 67173          0.002           0.3         0.021          0.003
# 67174          0.002           0.3         0.021          0.003
# 67175          0.002           0.3         0.021          0.003
#
#        PM10_incheon_0             datetime  SO2_incheon_1  CO_incheon_1  \
# 0                73.0  2015-01-01 00:00:00         0.0027           0.2
# ...

# %%
df.columns
# Out:
# Index(['SO2_incheon_0', 'CO_incheon_0', 'O3_incheon_0', 'NO2_incheon_0',
#        'PM10_incheon_0', 'datetime', 'SO2_incheon_1', 'CO_incheon_1',
#        'O3_incheon_1', 'NO2_incheon_1',
#        ...
#        'x0_1916060501.0_seoul_8', 'x0_4019060501.0_seoul_8',
#        'x0_7019160401.0_seoul_8', 'x0_7170190401.0_seoul_8',
#        'x0_7170191601.0_seoul_8', 'x0_7170401904.0_seoul_8',
#        'x0_7270160401.0_seoul_8', 'x0_7270190401.0_seoul_8',
#        'x0_7271701904.0_seoul_8', 'x0_717019160401.0_seoul_8'],
#       dtype='object', length=2518)

# %%
df.to_sql(name = 'Air_Pollution', con = engine, if_exists = 'append', index=False)
# Out:
# 67176

# %% [markdown]
# # csv 파일 불러오기

# %%
import os

path = './weather/'
file_list = os.listdir(path)
file_list_py= [file for file in file_list if file.endswith('.csv')]

# %%
file_list_py
# Out:
# ['paju.csv',
#  'dongducheon.csv',
#  'suwon.csv',
#  'incheon.csv',
#  'seoul.csv',
#  'bangryeongdo.csv',
#  'yangpyeong.csv',
#  'icheon.csv',
#  'ganghwado.csv']

# %%
# 백령도
df_bangryeongdo = pd.read_csv("./weather/bangryeongdo.csv")
df_bangryeongdo
# Out:
#                   datetime stnNm    ta   rn   ws     wd    hm    pv    td  \
# 0      2015-01-01 00:00:00   백령도  -5.0  0.0  8.7  290.0  40.0   1.7 -16.5
# 1      2015-01-01 01:00:00   백령도  -5.0  0.0  9.1  290.0  40.0   1.7 -16.5
# 2      2015-01-01 02:00:00   백령도  -5.2  0.0  7.9  290.0  53.0   2.2 -13.3
# 3      2015-01-01 03:00:00   백령도  -5.7  0.0  6.8  290.0  59.0   2.4 -12.4
# 4      2015-01-01 04:00:00   백령도  -6.2  0.0  5.9  290.0  65.0   2.5 -11.7
# ...                    ...   ...   ...  ...  ...    ...   ...   ...   ...
# 67195  2022-08-31 19:00:00   백령도  20.6  0.0  3.5  340.0  89.0  21.6  18.7
# 67196  2022-08-31 20:00:00   백령도  20.2  0.0  3.8  320.0  89.0  21.0  18.3
# 67197  2022-08-31 21:00:00   백령도  19.9  0.0  2.9  320.0  94.0  21.7  18.8
# 67198  2022-08-31 22:00:00   백령도  20.0  0.0  3.5  320.0  93.0  21.7  18.8
# 67199  2022-08-31 23:00:00   백령도  19.5  0.0  2.0  320.0  94.0  21.3  18.5
#
#            pa      ps   ss  icsr  dsnw  dc10Tca  dc10LmcsCa  lcsCh      vs  \
# ...

# %%
# 동두천
df_dongducheon= pd.read_csv("./weather/dongducheon.csv")
df_dongducheon
# Out:
#                   datetime stnNm    ta   rn   ws     wd    hm    pv    td  \
# 0      2015-01-01 00:00:00   동두천  -8.2  0.0  6.3  320.0  33.0   1.1 -21.6
# 1      2015-01-01 01:00:00   동두천  -8.2  0.0  5.5  290.0  33.0   1.1 -21.6
# 2      2015-01-01 02:00:00   동두천  -9.0  0.0  3.7  320.0  35.0   1.1 -21.7
# 3      2015-01-01 03:00:00   동두천  -9.3  0.0  3.6  320.0  36.0   1.1 -21.6
# 4      2015-01-01 04:00:00   동두천  -9.6  0.0  3.1  290.0  38.0   1.1 -21.3
# ...                    ...   ...   ...  ...  ...    ...   ...   ...   ...
# 67195  2022-08-31 19:00:00   동두천  22.4  0.0  0.6  110.0  80.0  21.6  18.7
# 67196  2022-08-31 20:00:00   동두천  20.1  0.0  1.1   50.0  92.0  21.6  18.7
# 67197  2022-08-31 21:00:00   동두천  19.2  0.0  0.6   50.0  93.0  20.6  18.0
# 67198  2022-08-31 22:00:00   동두천  18.7  0.0  0.4    0.0  94.0  20.2  17.7
# 67199  2022-08-31 23:00:00   동두천  18.4  0.0  0.5   50.0  96.0  20.2  17.7
#
#            pa      ps   ss  icsr  dsnw  dc10Tca  dc10LmcsCa  lcsCh      vs  \
# ...

# %%
# 수원
df_suwon = pd.read_csv("./weather/suwon.csv")
df_suwon
# Out:
#                   datetime stnNm    ta   rn   ws     wd    hm    pv    td  \
# 0      2015-01-01 00:00:00    수원  -6.2  0.0  4.2  320.0  34.0   1.3 -19.5
# 1      2015-01-01 01:00:00    수원  -6.2  0.0  5.2  320.0  34.0   1.3 -19.5
# 2      2015-01-01 02:00:00    수원  -6.8  0.0  4.5  320.0  38.0   1.4 -18.7
# 3      2015-01-01 03:00:00    수원  -7.1  0.0  3.7  320.0  39.0   1.4 -18.7
# 4      2015-01-01 04:00:00    수원  -7.4  0.0  4.6  320.0  38.0   1.3 -19.3
# ...                    ...   ...   ...  ...  ...    ...   ...   ...   ...
# 67195  2022-08-31 19:00:00    수원  22.4  0.0  1.1   20.0  84.0  22.7  19.5
# 67196  2022-08-31 20:00:00    수원  21.5  0.0  0.8   20.0  86.0  22.0  19.0
# 67197  2022-08-31 21:00:00    수원  21.8  0.0  0.9   70.0  86.0  22.4  19.3
# 67198  2022-08-31 22:00:00    수원  21.1  0.0  0.4    0.0  93.0  23.2  19.9
# 67199  2022-08-31 23:00:00    수원  20.5  0.0  0.0    0.0  96.0  23.1  19.8
#
#            pa      ps   ss  icsr  dsnw  dc10Tca  dc10LmcsCa  lcsCh      vs  \
# ...

# %%
# 파주
df_paju = pd.read_csv("./weather/paju.csv")
df_paju
# Out:
#                   datetime stnNm    ta   rn   ws     wd    hm    pv    td  \
# 0      2015-01-01 00:00:00    파주  -7.6  0.0  3.5  320.0  32.0   1.1 -21.4
# 1      2015-01-01 01:00:00    파주  -7.6  0.0  4.5  320.0  32.0   1.1 -21.4
# 2      2015-01-01 02:00:00    파주  -8.2  0.0  4.3  320.0  33.0   1.1 -21.6
# 3      2015-01-01 03:00:00    파주  -8.9  0.0  3.0  320.0  34.0   1.1 -21.9
# 4      2015-01-01 04:00:00    파주  -9.1  0.0  3.4  320.0  34.0   1.0 -22.1
# ...                    ...   ...   ...  ...  ...    ...   ...   ...   ...
# 67195  2022-08-31 19:00:00    파주  21.1  0.0  0.0    0.0  92.0  22.9  19.7
# 67196  2022-08-31 20:00:00    파주  20.0  0.0  0.0    0.0  95.0  22.1  19.1
# 67197  2022-08-31 21:00:00    파주  19.4  0.0  0.7  160.0  97.0  21.8  18.9
# 67198  2022-08-31 22:00:00    파주  19.4  0.0  0.1    0.0  99.0  22.2  19.2
# 67199  2022-08-31 23:00:00    파주  19.5  0.0  0.2    0.0  98.0  22.1  19.1
#
#            pa      ps   ss  icsr  dsnw  dc10Tca  dc10LmcsCa  lcsCh      vs  \
# ...

# %%
# 서울
df_seoul = pd.read_csv("./weather/seoul.csv")
df_seoul
# Out:
#                   datetime stnNm    ta   rn   ws     wd    hm    pv    td  \
# 0      2015-01-01 00:00:00    서울  -7.4  0.0  6.1  290.0  33.0   1.2 -20.9
# 1      2015-01-01 01:00:00    서울  -7.4  0.0  4.7  290.0  33.0   1.2 -20.9
# 2      2015-01-01 02:00:00    서울  -8.0  0.0  4.5  290.0  35.0   1.2 -20.8
# 3      2015-01-01 03:00:00    서울  -8.4  0.0  3.8  290.0  37.0   1.2 -20.5
# 4      2015-01-01 04:00:00    서울  -8.8  0.0  4.9  290.0  35.0   1.1 -21.5
# ...                    ...   ...   ...  ...  ...    ...   ...   ...   ...
# 67195  2022-08-31 19:00:00    서울  23.5  0.0  2.0   50.0  75.0  21.7  18.8
# 67196  2022-08-31 20:00:00    서울  22.4  0.0  2.0   20.0  80.0  21.6  18.7
# 67197  2022-08-31 21:00:00    서울  21.7  0.0  1.6  360.0  81.0  20.9  18.2
# 67198  2022-08-31 22:00:00    서울  21.1  0.0  1.0   20.0  83.0  20.6  18.0
# 67199  2022-08-31 23:00:00    서울  20.8  0.0  0.7  290.0  87.0  21.3  18.5
#
#            pa      ps   ss  icsr  dsnw  dc10Tca  dc10LmcsCa  lcsCh      vs  \
# ...

# %%
# 이천
df_icheon= pd.read_csv("./weather/icheon.csv")
df_icheon
# Out:
#                   datetime stnNm    ta   rn   ws     wd    hm    pv    td  \
# 0      2015-01-01 00:00:00    이천  -7.2  0.0  3.1  290.0  28.0   1.0 -22.6
# 1      2015-01-01 01:00:00    이천  -7.2  0.0  2.7  320.0  28.0   1.0 -22.6
# 2      2015-01-01 02:00:00    이천  -7.7  0.0  2.8  290.0  29.0   1.0 -22.6
# 3      2015-01-01 03:00:00    이천  -8.1  0.0  4.2  320.0  30.0   1.0 -22.6
# 4      2015-01-01 04:00:00    이천  -8.6  0.0  3.1  290.0  33.0   1.1 -22.0
# ...                    ...   ...   ...  ...  ...    ...   ...   ...   ...
# 67195  2022-08-31 19:00:00    이천  21.6  0.0  0.6  340.0  87.0  22.4  19.3
# 67196  2022-08-31 20:00:00    이천  20.5  0.0  0.3    0.0  94.0  22.5  19.4
# 67197  2022-08-31 21:00:00    이천  19.8  0.0  0.0    0.0  99.0  22.8  19.6
# 67198  2022-08-31 22:00:00    이천  20.0  0.0  0.0    0.0  98.0  22.8  19.6
# 67199  2022-08-31 23:00:00    이천  19.7  0.0  0.0    0.0  99.0  22.7  19.5
#
#            pa      ps   ss  icsr  dsnw  dc10Tca  dc10LmcsCa  lcsCh      vs  \
# ...

# %%
# 인천
df_incheon = pd.read_csv("./weather/incheon.csv")
df_incheon
# Out:
#                   datetime stnNm    ta   rn    ws     wd    hm    pv    td  \
# 0      2015-01-01 00:00:00    인천  -6.5  0.0  10.2  340.0  52.0   2.0 -14.7
# 1      2015-01-01 01:00:00    인천  -6.5  0.0   7.3  340.0  52.0   2.0 -14.7
# 2      2015-01-01 02:00:00    인천  -6.9  0.0   7.6  340.0  52.0   1.9 -15.1
# 3      2015-01-01 03:00:00    인천  -7.1  0.0   8.4  340.0  53.0   1.9 -15.0
# 4      2015-01-01 04:00:00    인천  -7.7  0.0   8.2  340.0  49.0   1.7 -16.5
# ...                    ...   ...   ...  ...   ...    ...   ...   ...   ...
# 67195  2022-08-31 19:00:00    인천  23.3  0.0   2.0  250.0  74.0  21.0  18.3
# 67196  2022-08-31 20:00:00    인천  23.0  0.0   1.9  250.0  77.0  21.6  18.7
# 67197  2022-08-31 21:00:00    인천  22.7  0.0   1.2  290.0  80.0  22.0  19.0
# 67198  2022-08-31 22:00:00    인천  22.4  0.0   0.9  290.0  83.0  22.4  19.3
# 67199  2022-08-31 23:00:00    인천  22.3  0.0   0.4    0.0  85.0  22.8  19.6
#
# ...

# %%
# 양평
df_yangpyeong = pd.read_csv("./weather/yangpyeong.csv")
df_yangpyeong
# Out:
#                   datetime stnNm    ta   rn   ws     wd    hm    pv    td  \
# 0      2015-01-01 00:00:00    양평  -6.4  0.0  4.9  290.0  32.0   1.2 -20.4
# 1      2015-01-01 01:00:00    양평  -6.4  0.0  4.9  320.0  32.0   1.2 -20.4
# 2      2015-01-01 02:00:00    양평  -7.0  0.0  3.8  320.0  32.0   1.2 -20.9
# 3      2015-01-01 03:00:00    양평  -7.4  0.0  4.7  320.0  34.0   1.2 -20.6
# 4      2015-01-01 04:00:00    양평  -8.0  0.0  4.2  320.0  35.0   1.2 -20.8
# ...                    ...   ...   ...  ...  ...    ...   ...   ...   ...
# 67195  2022-08-31 19:00:00    양평  20.5  0.0  0.6  290.0  92.0  22.1  19.1
# 67196  2022-08-31 20:00:00    양평  20.2  0.3  0.8  320.0  95.0  22.4  19.3
# 67197  2022-08-31 21:00:00    양평  20.0  0.1  0.8  320.0  94.0  21.8  18.9
# 67198  2022-08-31 22:00:00    양평  19.4  0.0  0.4    0.0  96.0  21.6  18.7
# 67199  2022-08-31 23:00:00    양평  19.4  0.0  0.4    0.0  97.0  21.8  18.9
#
#            pa      ps   ss  icsr  dsnw  dc10Tca  dc10LmcsCa  lcsCh      vs  \
# ...

# %%
# 강화도
df_ganghwado = pd.read_csv("./weather/ganghwado.csv")
df_ganghwado
# Out:
#                   datetime stnNm    ta   rn   ws     wd     hm    pv    td  \
# 0      2015-01-01 00:00:00    강화  -7.0  0.0  3.2  250.0   39.0   1.4 -18.6
# 1      2015-01-01 01:00:00    강화  -7.0  0.0  4.3  180.0   39.0   1.4 -18.6
# 2      2015-01-01 02:00:00    강화  -7.5  0.0  2.4  110.0   40.0   1.4 -18.8
# 3      2015-01-01 03:00:00    강화  -7.8  0.0  2.9  110.0   41.0   1.4 -18.7
# 4      2015-01-01 04:00:00    강화  -8.1  0.0  2.3  110.0   39.0   1.3 -19.6
# ...                    ...   ...   ...  ...  ...    ...    ...   ...   ...
# 67195  2022-08-31 19:00:00    강화  21.5  0.0  1.2  320.0   93.0  23.8  20.3
# 67196  2022-08-31 20:00:00    강화  20.5  0.0  0.9  320.0  100.0  24.0  20.4
# 67197  2022-08-31 21:00:00    강화  20.4  0.0  0.9  360.0  100.0  23.8  20.3
# 67198  2022-08-31 22:00:00    강화  20.5  0.0  0.6  340.0  100.0  24.0  20.4
# 67199  2022-08-31 23:00:00    강화  20.0  0.0  0.5  360.0  100.0  23.2  19.9
#
# ...

# %% [markdown]
# # DB에 CSV파일 넣기

# %%
# 백령도
df_bangryeongdo.to_sql(name = 'pollution_bangryeongdo', con = engine, if_exists = 'append', index=False)
# Out:
# 67200

# %%
# 동두천
df_dongducheon.to_sql(name = 'pollution_dongducheon', con = engine, if_exists = 'append', index=False)
# Out:
# 67200

# %%
# 수원
df_suwon.to_sql(name = 'pollution_suwon', con = engine, if_exists = 'append', index=False)
# Out:
# 67200

# %%
# 파주
df_paju.to_sql(name = 'pollution_paju', con = engine, if_exists = 'append', index=False)
# Out:
# 67200

# %%
# 서울
df_seoul.to_sql(name = 'pollution_seoul', con = engine, if_exists = 'append', index=False)
# Out:
# 67200

# %%
# 이천
df_icheon.to_sql(name = 'pollution_icheon', con = engine, if_exists = 'append', index=False)
# Out:
# 67200

# %%
# 인천
df_incheon.to_sql(name = 'pollution_incheon', con = engine, if_exists = 'append', index=False)
# Out:
# 67200

# %%
# 양평
df_yangpyeong .to_sql(name = 'pollution_yangpyeong', con = engine, if_exists = 'append', index=False)
# Out:
# 67200

# %%
# 강화도
df_ganghwado.to_sql(name = 'pollution_ganghwado', con = engine, if_exists = 'append', index=False)
# Out:
# 67200
